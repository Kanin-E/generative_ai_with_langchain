# %%
# setting the environment variables, the keys
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from config import set_environment
# for the keys - as explained early in chapter 2
set_environment()

# %% [markdown]
# # LangChain Common Expression Language (LCEL)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

# Create components
prompt = PromptTemplate.from_template("Tell me a joke about {topic}")
llm = ChatOpenAI()
output_parser = StrOutputParser()

# Chain them together using LCEL
chain = prompt | llm | output_parser

# Use the chain
result = chain.invoke({"topic": "programming"})
print(result)
# Out:
# Why do programmers prefer dark mode?
# Because the light attracts bugs!

# %% [markdown]
# # More complex expressions

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

chat = ChatGoogleGenerativeAI(model="gemini-2.5-pro")

# First chain generates a story
story_prompt = PromptTemplate.from_template("Write a short story about {topic}")
story_chain = story_prompt | chat | StrOutputParser()

# Second chain analyzes the story
analysis_prompt = PromptTemplate.from_template("Analyze the following story's mood:\n{story}")
analysis_chain = analysis_prompt | chat | StrOutputParser()

output_prompt = PromptTemplate.from_template(
    "Here's the story: \n{story}\n\nHere's the mood: \n{mood}"
)
# Combine chains
story_with_analysis = story_chain | analysis_chain

# Run the combined chain
result = story_with_analysis.invoke({"topic": "a rainy day"})
print(result)
# Out:
# Of course. Here is a detailed analysis of the story's mood.
#
# The mood of this story is not static; it undergoes a significant and beautifully rendered evolution. It begins with a deep sense of **melancholy and confinement**, transitions through a period of **restless agitation**, and finally resolves into a feeling of **cozy, contemplative peace and renewal**.
#
# ### 1. Initial Mood: Melancholy and Confinement
#
# The story opens by immersing the reader in a somber, oppressive atmosphere. The author achieves this through several techniques:
#
# *   **Color Palette:** The world is described in muted tones: "shades of grey," "pearly light," and a "Tuesday scrubbed of all its colour." This lack of vibrancy immediately establishes a bleak and listless mood.
# *   **Sensory Details:** The sounds are monotonous and mournful. The "rhythmic *shush* of tires," the "distant, mournful wail of a siren," and the "persistent tap-tap-tapping" create a soundscape that is draining rather than energizing.
# *   **Personification:** The rain is given human-like sadness. Each drop "seemed to carry a tiny weight of melancholy," directly telling the reader how to feel about the weather.
# *   **Protagonist's Internal State:** Leo’s feelings mirror the external world. The day is something "to be endured." His plans are "washed away," and his apartment, a "sanctuary," now feels like a "cage." This sense of being trapped and powerless is central to the initial mood.
#
# ### 2. Transitional Mood: Restless Agitation
#
# As the weather intensifies, so does the mood, shifting from passive melancholy to an active, frustrated restlessness.
#
# *   **Escalating Weather:** The "drizzle" thickens into a "downpour." The sky becomes a "bruised, angry purple," and the sound on the roof escalates from a "tap" to a "frantic drumming." The storm's growing energy is a metaphor for Leo's internal state.
# *   **Character's Actions:** Leo's mood is no longer passive. He begins "pacing" and is unable to focus on a simple task like reading. The story states that the "restless energy of the storm had seeped through the walls and into his bones," making the connection explicit. The mood is now tense and agitated, full of nervous energy with no outlet.
#
# ### 3. Final Mood: Cozy, Contemplative Peace and Renewal
#
# The turning point occurs when Leo makes a conscious decision to "lean into" the chaos instead of fighting it. This choice completely transforms the story's mood.
#
# *   **A Shift in Sensory Input:** Leo actively introduces new, positive sensory details that compete with the storm. The "soaring notes of a saxophone" create a "beautiful, vibrant chaos," and the comforting smell and taste of a "grilled cheese sandwich" ground him in the present moment.
# *   **Change in Perception:** The author uses powerful metaphors to signal the shift. The "cage" becomes a "cocoon," transforming the feeling of confinement into one of safety, warmth, and quiet transformation. The "grey" is no longer "bleak" but "soft and comforting." The rain's drumming is no longer impatient but a "steady, lulling rhythm."
# *   **Imagery of Hope and Renewal:** The final paragraphs are filled with images of cleansing and optimism. The post-rain air has the "smell of renewal." The final rays of sunlight turn puddles into "liquid gold," finding beauty and value in the remnants of the storm. The single image of the woman in the "bright yellow raincoat" serves as a "slash of defiant sunshine," a symbol of resilience and warmth amidst the gloom.
#
# **In conclusion, the story masterfully guides the reader on an emotional journey.** It starts with an oppressive, melancholic mood, reflecting a feeling of being trapped by circumstance. It then builds into a tense agitation before resolving into a profoundly peaceful and hopeful state. The central theme is that peace is not found in the absence of a storm, but in changing one's relationship to it—by finding beauty, comfort, and a moment of quiet magic within the chaos.
